# %% [markdown]
# <a href="https://colab.research.google.com/github/oink3388-IoT/__2026_05_09_chihlee_python__/blob/main/2026_05_09_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Python!")
# Out:
# Hello Python!

# %% [markdown]
# ### 這是第一節上課的講義
# 下面是數學運算的介紹
#
# 先介紹*變數*,**數學運算子**
#
# #### 專有名詞介紹
#
# - 變數
# - 數學運算子
#
# 1. 運算子,運算元
# 2. 運算是,敘述式
