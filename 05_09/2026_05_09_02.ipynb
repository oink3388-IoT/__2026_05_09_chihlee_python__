# %% [markdown]
# <a href="https://colab.research.google.com/github/oink3388-IoT/__2026_05_09_chihlee_python__/blob/main/05_09/2026_05_09_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###數學運算

# %%
# 建立變數

10   #整數(int)
10.0  #浮點數(float)
"10.5" #字串(str)
'10.5' #字串(str)
# Out:
# '10.5'

# %%
10+5
# Out:
# 15

# %%
10.0+5.0
# Out:
# 15.0

# %%
print(10+5) # 敘述式(stetement)
print(10.0+5.0)
print("10.0+5.0")
print(10.0+5)
print(type(10.0+5))
# Out:
# 15
# 15.0
# 10.0+5.0
# 15.0
# <class 'float'>

# %%
a=5 #等號是"指定運算子"
b=10
print(a) #print是敘述式
print(b) #print是敘述式
a #只寫a是運算式
# Out:
# 5
# 10
# 5

# %%
a=10 #等號是"指定運算子"
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
a=5
b=10
total=a+b #加號（運算子）先處理，得到的結果再透過等號把15傳到變數total去
print(total)
# Out:
# 15

# %%
print(2+3*4)
print((2+3)*4)
print(2 * (1 + 2) ** 2 - 2 ** 2 * 2)
# Out:
# 14
# 20
# 10
