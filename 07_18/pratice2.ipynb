# %%
import pandas as pd
import numpy as np

data=pd.Series(np.random.randn(9),
                   index=[['a','a','a','b','b','c','c','d','d'],
                          [1,2,3,1,2,3,1,2,3]])

data
# Out:
# a  1    1.968305
#    2   -1.090904
#    3   -0.031989
# b  1   -0.719148
#    2   -0.150100
# c  3   -1.494247
#    1    2.718077
# d  2    1.657304
#    3    2.125006
# dtype: float64

# %%
data1=data.unstack()
data1
# Out:
#           1         2         3
# a  1.968305 -1.090904 -0.031989
# b -0.719148 -0.150100       NaN
# c  2.718077       NaN -1.494247
# d       NaN  1.657304  2.125006

# %%
data1.stack()
# Out:
# <bound method DataFrame.stack of           1         2         3
# a  1.968305 -1.090904 -0.031989
# b -0.719148 -0.150100       NaN
# c  2.718077       NaN -1.494247
# d       NaN  1.657304  2.125006>
