# %%
#建立工廠

class Person:
    #pass
    #實體方法
    def __init__(self): #自訂初始化
        print("初始化：一個新的人被建立了")

# %%
p1 = Person()
type(p1)
# Out:
# 初始化：一個新的人被建立了
# __main__.Person

# %%
class Person:
    #pass
    #實體方法
    def __init__(self,name):
        self.name = name

# %%
p2=Person("Steve")
p2.name
# Out:
# 'Steve'

# %%
p3=Person("Jenny")
p3.name
# Out:
# 'Jenny'
